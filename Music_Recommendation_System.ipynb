# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
path="/content/drive/MyDrive/Colab Notebooks/spotify_millsongdata.csv"
df=pd.read_csv(path)
print(df.head)
# Out:
# Mounted at /content/drive
# <bound method NDFrame.head of              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...
#
# [57650 rows x 4 columns]>

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df =df.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#                    artist                               song  \
# 0          Point Of Grace                         Day By Day
# 1             The Monkees                     Tear Drop City
# 2  Nitty Gritty Dirt Band           You Made Life Good Again
# 3           Nat King Cole                     Deck The Halls
# 4           Queen Latifah                         Poetry Man
# 5            Eric Clapton                      Man Overboard
# 6              Paul Simon           When Numbers Get Serious
# 7             Soundgarden  Searching With My Good Eye Closed
# 8           Ariana Grande                           Lovin It
# 9           Kenny Loggins                        I'm Alright
#
#                                                 text
# 0  I'm not unhappy, but I'd take the train today ...
# 1  About as low as I felt in a long time  \r\nAnd...
# 2  I'm always looking for a minute that we can st...
# 3  Deck the halls with boughs of holly  \r\nFa-la...
# 4  You make me laugh  \r\nCause your eyes they li...
# 5  You say you do when you don't, you say you wil...
# 6  I have a number in my head  \r\nThought I don'...
# 7  Painted blue across my eyes  \r\nAnd tied the ...
# 8  (Hoo) (It's the Rascals)  \r\n  \r\nBaby don't...
# 9  I'm alright  \r\nNobody worry 'bout me  \r\nWh...

# %%
df['text'][0]
# Out:
# "I'm not unhappy, but I'd take the train today  \r\nIf you'd let me, if you'd let me  \r\nThey may be clapping for me, but I wait  \r\nFor you to come get me, some come and get me  \r\n  \r\n[Chorus]  \r\n'Cause day by day you're coming closer  \r\nMaking our way clearer and straighter  \r\nTurning our faces into the light  \r\nAnd I can't wait to fall at your glory  \r\nOn my face, god of the morning  \r\nYou're coming closer day by day  \r\n  \r\nSomebody told me I could travel the world  \r\nTo find beauty, to find beauty  \r\nBut to behold it I would have to carry it  \r\nWithin me, yeah well it's in me  \r\n  \r\n[Chorus]  \r\n  \r\nGive me a mission if I've still got the time  \r\n'Cause I'm open, yeah I'm open  \r\nBe my vision and I'll be your delight  \r\n  \r\n'Cause I'm goin' wherever you're goin'  \r\nTurning faces into the light  \r\nAnd I can't wait to fall at your glory  \r\nOn my face, god of the morning  \r\nYou're coming closer day by day  \r\n  \r\n[Chorus]\r\n\r\n"

# %%
# df = df.sample(5000)

# %%
df.shape
# Out:
# (5000, 3)

# %% [markdown]
# Text Cleaning/ Text Preprocessing

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
def token(txt):
    token = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in token]
    return " ".join(stemming)

# %%
token("you are beautiful, beauty")
# Out:
# 'you are beauti , beauti'

# %%
df['text'] = df['text'].apply(lambda x: token(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidvector.fit_transform(df['text'])
similarity = cosine_similarity(matrix)

# %%
similarity[0]
# Out:
# array([1.        , 0.01885246, 0.16731356, ..., 0.00864627, 0.07181471,
#        0.08105342])

# %%
df[df['song'] == 'Crying Over You']
# Out:
#      artist             song  \
# 1091   UB40  Crying Over You
#
#                                                    text
# 1091  cri over you in the morn cri over you in the e...

# %%
def recommendation(song_df):
    idx = df[df['song'] == song_df].index[0]
    distances = sorted(list(enumerate(similarity[idx])),reverse=True,key=lambda x:x[1])

    songs = []
    for m_id in distances[1:21]:
        songs.append(df.iloc[m_id[0]].song)

    return songs

# %%
recommendation('Crying Over You')
# Out:
# ['Crying',
#  "Don't Come Cryin' To Me - Previously Unreleased",
#  'Crybaby',
#  "Don't Cry No Tears",
#  'Cry Me A River',
#  'Cry Me A River',
#  'Fly Away',
#  'Crying Games',
#  'Die Die My Darling',
#  'Lovers In The Night',
#  'Blue Eyes Crying In The Rain',
#  "Don't Let The Sun Catch You Crying",
#  'Lonesome Lullaby',
#  "Who's Crying Now",
#  "I'm So Lonesome I Could Cry",
#  'Everyday',
#  'For Crying Out Loud',
#  'Only My Soul',
#  "Baby, I Don't Cry Over You",
#  'Blue Eyes Crying In The Rain']

# %%
import pickle
pickle.dump(similarity,open('similarity.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))
